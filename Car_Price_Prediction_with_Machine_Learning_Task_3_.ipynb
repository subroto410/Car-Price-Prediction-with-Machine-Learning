# %%
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
df=pd.read_csv('/content/drive/MyDrive/dataset/car data.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
input=df.drop(['Car_Name','Owner','Selling_type'],axis='columns')
target=df.Selling_Price
input
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms Fuel_Type Transmission
# 0    2014           3.35           5.59       27000    Petrol       Manual
# 1    2013           4.75           9.54       43000    Diesel       Manual
# 2    2017           7.25           9.85        6900    Petrol       Manual
# 3    2011           2.85           4.15        5200    Petrol       Manual
# 4    2014           4.60           6.87       42450    Diesel       Manual
# ..    ...            ...            ...         ...       ...          ...
# 296  2016           9.50          11.60       33988    Diesel       Manual
# 297  2015           4.00           5.90       60000    Petrol       Manual
# 298  2009           3.35          11.00       87934    Petrol       Manual
# 299  2017          11.50          12.50        9000    Diesel       Manual
# 300  2016           5.30           5.90        5464    Petrol       Manual
#
# [301 rows x 6 columns]

# %%
from sklearn.preprocessing import LabelEncoder
Numerics=LabelEncoder()

# %%
input['Fuel_Type']=Numerics.fit_transform(input['Fuel_Type'])
input['Transmission']=Numerics.fit_transform(input['Transmission'])

input
# Out:
#      Year  Selling_Price  Present_Price  Driven_kms  Fuel_Type  Transmission
# 0    2014           3.35           5.59       27000          2             1
# 1    2013           4.75           9.54       43000          1             1
# 2    2017           7.25           9.85        6900          2             1
# 3    2011           2.85           4.15        5200          2             1
# 4    2014           4.60           6.87       42450          1             1
# ..    ...            ...            ...         ...        ...           ...
# 296  2016           9.50          11.60       33988          1             1
# 297  2015           4.00           5.90       60000          2             1
# 298  2009           3.35          11.00       87934          2             1
# 299  2017          11.50          12.50        9000          1             1
# 300  2016           5.30           5.90        5464          2             1
#
# [301 rows x 6 columns]

# %%
input_s=input.drop(['Fuel_Type','Transmission','Selling_Price'],axis='columns')
input_s
# Out:
#      Year  Present_Price  Driven_kms
# 0    2014           5.59       27000
# 1    2013           9.54       43000
# 2    2017           9.85        6900
# 3    2011           4.15        5200
# 4    2014           6.87       42450
# ..    ...            ...         ...
# 296  2016          11.60       33988
# 297  2015           5.90       60000
# 298  2009          11.00       87934
# 299  2017          12.50        9000
# 300  2016           5.90        5464
#
# [301 rows x 3 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(input_s,target,test_size=0.2,random_state=0)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred=model.predict(x_test)
print(pred)
# Out:
# [ 6.06989402e+00 -8.66343325e-02  4.22460084e+00  7.67402332e+00
#   1.23003200e+01  4.84199665e+00  3.37792171e+00  2.09558376e+00
#   3.84413917e+00  4.70143861e+00  1.81399250e+00  2.29901053e+00
#   5.15577084e+00  6.38478104e+00  7.25503762e+00  1.40190780e+01
#   6.11755312e+00  4.28544313e+00  5.89722497e-03  3.20328790e+00
#   3.52024218e+00  4.70683686e+00  5.16492715e+00  8.69892377e+00
#  -1.56349312e+00  2.70280025e+00 -1.67205277e-01  1.47846733e+00
#   4.53998868e-01  6.14296000e+00  2.43051205e+00  5.87183895e+00
#   1.37057820e+00  6.31087196e+00  3.58571797e+00  2.57089364e+00
#   5.71074979e+00  5.30215577e+00 -1.53354366e+00  7.93923592e+00
#   7.73107312e+00  1.91025649e+01  4.24238200e+00  4.94042186e+00
#   4.94074440e+00  8.68724084e+00  6.94538010e-01  2.40580825e+00
#   5.40276572e+00  5.69361798e+00  6.98688445e+00  4.05442127e+00
#   5.14374848e+00  1.95608546e+01  2.56270158e+00  2.07685581e+00
# ...

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# ...

# %%
import matplotlib.pyplot as plt

# %%
training_data_prediction = model.predict(input_s)

# %%
from sklearn import metrics

# %%
error_score = metrics.r2_score(target,training_data_prediction)
print("R squared Error :",error_score)
# Out:
# R squared Error : 0.8483509708016401

# %%
plt.scatter(target, training_data_prediction)
plt.xlabel("Actual price")
plt.ylabel("Predicted Price")
plt.title("Actual Prices vs Predicted Prices")
plt.show()
